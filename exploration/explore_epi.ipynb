# %%
from build_epi_ga_df import *
import pandas as pd
from patsy import dmatrices
import plotly.express as px
import plotly.graph_objects as go
import statsmodels.api as sm
from sklearn.model_selection import train_test_split


data_dir = "../data/erin_data"

ga_data, epi_data = build_epi_ga_data(data_dir)

drop_cols = ["age_at_ga", "n_extractions", "n_primary_extract",
             "n_perm_extract", "has_bib1kc", "res6mcage_ga", "Epi", "GATx",
             "ddscareindex", "describe_health_q", "has_diagnosis_q",
             "hospital_admission_q", "looked_after_child"]

epi_data.drop(drop_cols, axis=1, inplace=True)
epi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 200 to 1404
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   decayed_teeth            354 non-null    float64
#  1   missing_teeth            354 non-null    float64
#  2   filled_teeth             354 non-null    float64
#  3   dmft                     354 non-null    float64
#  4   res6mcage                354 non-null    float64
#  5   res6mcbetterstart        354 non-null    object
#  6   gender                   354 non-null    object
#  7   father_age_at_q          111 non-null    float64
#  8   mother_age_at_q          295 non-null    float64
#  9   on_benefits              294 non-null    object
#  10  ethnicity                345 non-null    object
#  11  english_additional_lang  349 non-null    object
#  12  special_ed_needs         350 non-null    object
#  13  father_highest_ed        294 non-null    object
#  14  mother_highest_ed        295 non-null    object
#  15  mother_ethnicity         295 non-null    object
#  16  age_father_complete_ed   105 non-null    object
#  17  father_birthplace        107 non-null    object
#  18  imd_2010_decile          294 non-null    float64
#  19  socio_economic_pos       295 non-null    object
#  20  age_mother_moved_uk      119 non-null    float64
#  21  mother_birthplace        295 non-null    object
#  22  questionaire_language    295 non-null    object
# dtypes: float64(9), object(14)
# memory usage: 66.4+ KB

# %%
mother_english = epi_data.mother_ethnicity == "White British"
moved_is_na = epi_data.age_mother_moved_uk.isna()
change_cols = mother_english & moved_is_na
epi_data.loc[change_cols, "age_mother_moved_uk"] = 0

fill_values = {
 "father_age_at_q": epi_data.father_age_at_q.mean(),
 "mother_age_at_q": epi_data.mother_age_at_q.mean(),
 "on_benefits": "Don't know",
 "ethnicity": "Other",
 "english_additional_lang": "Don't know",
 "special_ed_needs": "Don't know",
 "father_highest_ed": "Don't know",
 "mother_highest_ed": "Don't know",
 "mother_ethnicity": "Other",
 "age_father_complete_ed": "Don't know",
 "father_birthplace": "Other",
 "imd_2010_decile": epi_data.imd_2010_decile.median(),
 "socio_economic_pos": "Don't know",
 "age_mother_moved_uk": epi_data.age_mother_moved_uk.median(),
 "mother_birthplace": "Other",
 "questionaire_language": "English",
}

for feature, value in fill_values.items():
    epi_data[feature] = epi_data[feature].fillna(value)

epi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 200 to 1404
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   decayed_teeth            354 non-null    float64
#  1   missing_teeth            354 non-null    float64
#  2   filled_teeth             354 non-null    float64
#  3   dmft                     354 non-null    float64
#  4   res6mcage                354 non-null    float64
#  5   res6mcbetterstart        354 non-null    object
#  6   gender                   354 non-null    object
#  7   father_age_at_q          354 non-null    float64
#  8   mother_age_at_q          354 non-null    float64
#  9   on_benefits              354 non-null    object
#  10  ethnicity                354 non-null    object
#  11  english_additional_lang  354 non-null    object
#  12  special_ed_needs         354 non-null    object
#  13  father_highest_ed        354 non-null    object
#  14  mother_highest_ed        354 non-null    object
#  15  mother_ethnicity         354 non-null    object
#  16  age_father_complete_ed   354 non-null    object
#  17  father_birthplace        354 non-null    object
#  18  imd_2010_decile          354 non-null    float64
#  19  socio_economic_pos       354 non-null    object
#  20  age_mother_moved_uk      354 non-null    float64
#  21  mother_birthplace        354 non-null    object
#  22  questionaire_language    354 non-null    object
# dtypes: float64(9), object(14)
# memory usage: 66.4+ KB

# %%
X_train, X_test, _, _ = train_test_split(epi_data.drop("dmft", axis=1),
                                                       epi_data.dmft,
                                                       test_size=0.33,
                                                       random_state=42)
train_idxs = X_train.index
test_idxs = X_test.index

drop_cols = ["decayed_teeth", "missing_teeth", "filled_teeth"]
train_dat = epi_data.loc[train_idxs].drop(drop_cols, axis=1)
test_dat = epi_data.loc[test_idxs].drop(drop_cols, axis=1)

# %%
features = train_dat.drop("dmft", axis=1).columns
patsy_string = "dmft ~ "
patsy_string += " + ".join(features)
y, X = dmatrices(patsy_string, data=train_dat, return_type="dataframe")

top_3_models = pd.DataFrame({
    "features": [],
    "rsquared": [],
    "f": []
})

def score_epi_model(features, show_summary=False):
    mod = sm.OLS(y, X[features])
    res = mod.fit()
    if show_summary:
        print(res.summary())
    return res.rsquared_adj, res.fvalue

model_has_improved = True
loop_no = 0
while model_has_improved:
    model_has_improved = False
    loop_no += 1

    top_models_this_loop = {
        "features": [],
        "rsquared": [],
        "f": []
    }

    if loop_no == 1:
        for feature in X.columns:
            rsquared, f = score_epi_model([feature])
            top_models_this_loop["features"].append([feature])
            top_models_this_loop["rsquared"].append(rsquared)
            top_models_this_loop["f"].append(f)
    else:
        for test_feature in X.columns:
            for extra_features in top_3_models.features:
                if test_feature in extra_features:
                    continue
                model_features = [test_feature] + extra_features
                rsquared, f = score_epi_model(model_features)
                if rsquared > top_3_models.rsquared.max():
                    top_models_this_loop["features"].append(model_features)
                    top_models_this_loop["rsquared"].append(rsquared)
                    top_models_this_loop["f"].append(f)


    if len(top_models_this_loop["features"]):
        model_has_improved = True
        top_3_models = (pd.DataFrame(top_models_this_loop)
                        .sort_values("rsquared", ascending=False)
                        .iloc[:3, :])

    print("=" * 80)
    print(f"Loop Number {loop_no} - start")
    print(f"Top 3 Models")
    print(top_3_models)
# Out:
# ================================================================================
# Loop Number 1 - start
# Top 3 Models
#              features  rsquared           f
# 52        [res6mcage]  0.305884  105.441610
# 53  [father_age_at_q]  0.304639  104.830317
# 54  [mother_age_at_q]  0.289031   97.347869
# ================================================================================
# Loop Number 2 - start
# Top 3 Models
#                                              features  rsquared          f
# 63         [questionaire_language[T.Urdu], res6mcage]  0.348942  64.511315
# 64   [questionaire_language[T.Urdu], father_age_at_q]  0.348917  64.504443
# 14  [english_additional_lang[T.Yes], father_age_at_q]  0.342097  62.617641
# ================================================================================
# Loop Number 3 - start
# Top 3 Models
#                                              features  rsquared          f
# 23  [mother_highest_ed[T.Don't know], questionaire...  0.375696  48.541002
# 22  [mother_highest_ed[T.Don't know], questionaire...  0.375551  48.511560
# 40  [socio_economic_pos[T.Don't know], questionair...  0.375062  48.412485
# ================================================================================
# Loop Number 4 - start
# Top 3 Models
#                                              features  rsquared          f
# 24  [mother_highest_ed[T.<5 GCSE equivalent], moth...  0.391489  39.118860
# 25  [mother_highest_ed[T.<5 GCSE equivalent], moth...  0.389864  38.859562
# 26  [mother_highest_ed[T.<5 GCSE equivalent], soci...  0.389057  38.731297
# ================================================================================
# Loop Number 5 - start
# Top 3 Models
#                                              features  rsquared          f
# 3   [ethnicity[T.White British], mother_highest_ed...  0.397764  32.306725
# 9   [english_additional_lang[T.Yes], mother_highes...  0.397736  32.303007
# 25  [imd_2010_decile, mother_highest_ed[T.<5 GCSE ...  0.396549  32.148278
# ================================================================================
# Loop Number 6 - start
# Top 3 Models
#                                              features  rsquared          f
# 9   [mother_highest_ed[T.Higher than A-level], eth...  0.403207  27.687088
# 4   [father_highest_ed[T.Higher than A-level], eth...  0.401634  27.513063
# 15  [mother_ethnicity[T.White British], ethnicity[...  0.401481  27.496283
# ================================================================================
# Loop Number 7 - start
# Top 3 Models
#                                              features  rsquared          f
# 4   [mother_highest_ed[T.Higher than A-level], mot...  0.406074  24.148514
# 8   [mother_ethnicity[T.White British], mother_hig...  0.406074  24.148514
# 10  [age_father_complete_ed[T.17-19], mother_highe...  0.404551  24.002704
# ================================================================================
# Loop Number 8 - start
# Top 3 Models
#                                             features  rsquared          f
# 6  [mother_ethnicity[T.White British], age_father...   0.40789  21.407954
# 7  [age_father_complete_ed[T.17-19], mother_highe...   0.40789  21.407954
# 8  [age_father_complete_ed[T.17-19], mother_ethni...   0.40789  21.407954
# ================================================================================
# Loop Number 9 - start
# Top 3 Models
#                                             features  rsquared          f
# 0  [special_ed_needs[T.SEN Support], mother_ethni...  0.408754  19.205381
# 1  [special_ed_needs[T.SEN Support], age_father_c...  0.408754  19.205381
# 2  [special_ed_needs[T.SEN Support], age_father_c...  0.408754  19.205381
# ================================================================================
# Loop Number 10 - start
# Top 3 Models
#                                             features  rsquared          f
# 3  [mother_highest_ed[T.Foreign Unknown], special...   0.40942  17.430049
# 5  [mother_highest_ed[T.Foreign Unknown], special...   0.40942  17.430049
# 4  [mother_highest_ed[T.Foreign Unknown], special...   0.40942  17.430049
# ================================================================================
# Loop Number 11 - start
# Top 3 Models
#                                             features  rsquared          f
# 6  [mother_birthplace[T.Other], mother_highest_ed...  0.411294  16.052518
# 7  [mother_birthplace[T.Other], mother_highest_ed...  0.411294  16.052518
# 8  [mother_birthplace[T.Other], mother_highest_ed...  0.411294  16.052518
# ================================================================================
# Loop Number 12 - start
# Top 3 Models
#                                             features  rsquared          f
# 3  [father_highest_ed[T.Foreign Unknown], mother_...  0.412264  14.853535
# 5  [father_highest_ed[T.Foreign Unknown], mother_...  0.412264  14.853535
# 4  [father_highest_ed[T.Foreign Unknown], mother_...  0.412264  14.853535
# ================================================================================
# Loop Number 13 - start
# Top 3 Models
#                                             features  rsquared          f
# 0  [questionaire_language[T.Mirpuri/Punjabi], fat...  0.412385  13.794277
# 1  [questionaire_language[T.Mirpuri/Punjabi], fat...  0.412385  13.794277
# 2  [questionaire_language[T.Mirpuri/Punjabi], fat...  0.412385  13.794277
# ================================================================================
# Loop Number 14 - start
# Top 3 Models
#                                             features  rsquared          f
# 0  [questionaire_language[T.Mirpuri/Punjabi], fat...  0.412385  13.794277
# 1  [questionaire_language[T.Mirpuri/Punjabi], fat...  0.412385  13.794277
# 2  [questionaire_language[T.Mirpuri/Punjabi], fat...  0.412385  13.794277

# %%
best_features = top_3_models.iloc[0,:].features
patsy_string = "dmft ~ "
patsy_string += " + ".join(best_features)
y, X = dmatrices(patsy_string,
                 data=epi_data,
                 return_type="dataframe")
epi_data.loc[train_idxs]
# Out:
#       decayed_teeth  missing_teeth  filled_teeth  dmft  res6mcage  \
# 1155            0.0            0.0           0.0   0.0       66.0
# 1325            3.0            0.0           0.0   3.0       66.0
# 1169            0.0            0.0           0.0   0.0       66.0
# 1082            0.0            0.0           0.0   0.0       66.0
# 1087            0.0            0.0           0.0   0.0       66.0
# ...             ...            ...           ...   ...        ...
# 1122            0.0            0.0           0.0   0.0       66.0
# 1157            0.0            0.0           0.0   0.0       66.0
# 1321            0.0            2.0           0.0   2.0       60.0
# 1399            9.0            0.0           0.0   9.0       66.0
# 1153            0.0            0.0           0.0   0.0       66.0
#
#      res6mcbetterstart  gender  father_age_at_q  mother_age_at_q on_benefits  \
# 1155                No    Male            250.0            234.0          No
# 1325                No    Male              NaN              NaN         NaN
# 1169               Yes  Female              NaN            303.0         Yes
# 1082               Yes  Female              NaN            268.0          No
# 1087               Yes    Male              NaN            382.0         Yes
# ...                ...     ...              ...              ...         ...
# 1122                No    Male            431.0              NaN         NaN
# 1157                No    Male            554.0            469.0         Yes
# 1321                No  Female              NaN            411.0          No
# 1399                No    Male              NaN            378.0         Yes
# 1153               Yes  Female              NaN            295.0          No
#
#       ...    father_highest_ed    mother_highest_ed mother_ethnicity  \
# 1155  ...    5 GCSE equivalent   A-level equivalent    White British
# 1325  ...                  NaN                  NaN              NaN
# 1169  ...    5 GCSE equivalent  Higher than A-level        Pakistani
# 1082  ...           Don't know    5 GCSE equivalent        Pakistani
# 1087  ...  Higher than A-level    5 GCSE equivalent        Pakistani
# ...   ...                  ...                  ...              ...
# 1122  ...                  NaN                  NaN              NaN
# 1157  ...   <5 GCSE equivalent   <5 GCSE equivalent    White British
# 1321  ...                Other   A-level equivalent    White British
# 1399  ...                Other   <5 GCSE equivalent        Pakistani
# 1153  ...           Don't know                Other    White British
#
#      age_father_complete_ed father_birthplace imd_2010_decile  \
# 1155                  17-19    United Kingdom             1.0
# 1325                    NaN               NaN             NaN
# 1169                    NaN               NaN             1.0
# 1082                    NaN               NaN             3.0
# 1087                    NaN               NaN             1.0
# ...                     ...               ...             ...
# 1122                    NaN               NaN             NaN
# 1157                  17-19    United Kingdom             2.0
# 1321                    NaN               NaN             1.0
# 1399                    NaN               NaN             2.0
# 1153                    NaN               NaN             1.0
#
#                socio_economic_pos age_mother_moved_uk  mother_birthplace  \
# 1155         Employed not mat dep                 NaN            England
# 1325                          NaN                 NaN                NaN
# 1169         Employed not mat dep                 NaN           Pakistan
# 1082          Benefits but coping                 NaN           Pakistan
# 1087  Employed no access to money                23.0           Pakistan
# ...                           ...                 ...                ...
# 1122                          NaN                 NaN                NaN
# 1157  Employed no access to money                 NaN            England
# 1321         Employed not mat dep                 NaN            England
# 1399          Benefits but coping                16.0           Pakistan
# 1153  Employed no access to money                 NaN            England
#
#      questionaire_language
# 1155               English
# 1325                   NaN
# 1169               English
# 1082               English
# 1087               English
# ...                    ...
# 1122                   NaN
# 1157               English
# 1321               English
# 1399               English
# 1153               English
#
# [237 rows x 23 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 201 to 1396
# Data columns (total 34 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Intercept                                 37 non-null     float64
#  1   special_ed_needs[T.Not SEN]               37 non-null     float64
#  2   special_ed_needs[T.SEN Support]           37 non-null     float64
#  3   mother_birthplace[T.England]              37 non-null     float64
#  4   mother_birthplace[T.India]                37 non-null     float64
#  5   mother_birthplace[T.Other]                37 non-null     float64
#  6   mother_birthplace[T.Pakistan]             37 non-null     float64
#  7   mother_birthplace[T.Philippines]          37 non-null     float64
#  8   mother_birthplace[T.Poland]               37 non-null     float64
#  9   mother_birthplace[T.Scotland]             37 non-null     float64
#  10  mother_birthplace[T.Sri Lanka]            37 non-null     float64
#  11  mother_birthplace[T.Wales]                37 non-null     float64
#  12  father_highest_ed[T.<5 GCSE equivalent]   37 non-null     float64
#  13  father_highest_ed[T.A-level equivalent]   37 non-null     float64
#  14  father_highest_ed[T.Don't know]           37 non-null     float64
#  15  father_highest_ed[T.Foreign Unknown]      37 non-null     float64
#  16  father_highest_ed[T.Higher than A-level]  37 non-null     float64
#  17  father_highest_ed[T.Other]                37 non-null     float64
#  18  res6mcbetterstart[T.Yes]                  37 non-null     float64
#  19  ethnicity[T.Pakistani]                    37 non-null     float64
#  20  ethnicity[T.White British]                37 non-null     float64
#  21  age_father_complete_ed[T.17-19]           37 non-null     float64
#  22  age_father_complete_ed[T.20 or over]      37 non-null     float64
#  23  mother_highest_ed[T.<5 GCSE equivalent]   37 non-null     float64
#  24  mother_highest_ed[T.A-level equivalent]   37 non-null     float64
#  25  mother_highest_ed[T.Don't know]           37 non-null     float64
#  26  mother_highest_ed[T.Foreign Unknown]      37 non-null     float64
#  27  mother_highest_ed[T.Higher than A-level]  37 non-null     float64
#  28  mother_highest_ed[T.Other]                37 non-null     float64
#  29  questionaire_language[T.Mirpuri/Punjabi]  37 non-null     float64
#  30  questionaire_language[T.Urdu]             37 non-null     float64
#  31  imd_2010_decile                           37 non-null     float64
#  32  age_mother_moved_uk                       37 non-null     float64
#  33  father_age_at_q                           37 non-null     float64
# dtypes: float64(34)
# memory usage: 10.1 KB

# %%
mod = sm.OLS(y, X.loc[train_idxs])
res = mod.fit()
print(res.summary())
# Out:
# 1057    10.000000
# 1045     6.032286
# 1279     1.000000
# 1391     6.999315
# 1363     4.029547
# dtype: float64
